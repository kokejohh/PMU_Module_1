# %% [markdown]
# <a href="https://colab.research.google.com/github/kokejohh/PMU_Module_1/blob/main/Copy_of_pandas_quiz_ep2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Your Information

full_name =  'pitchakorn thiprangsi' #@param {type:"string"}
student_id =  ''  #@param {type:"string"}

#@markdown ---

# %% [markdown]
# # **Pandas Quiz Ep.2**
# > ## *Author* : [Rathachai CHAWUTHAI](https://rathachai.creatier.pro/) , Ph.D
# > ### *Affiliation* : Computer Engineering, King Mongkut's Institute of Technology Ladkrabang (KMITL)
# > #### *Updated Date* : 2022-03-23
# ---

# %% [markdown]
# ## Instruction
#
# Write Python code to answer each question. In general, it uses 1 line of code for each answer.
#
# ## คำสั่ง
#
# จงเขียนโค้ดภาษาไพธอนเพื่อตอบคำถาม
# ซึ่งโดยทั่วไปคำตอบแต่ละข้อจะใช้เพียง 1 บรรทัดโค้ด

# %% [markdown]
# ## Q0
#
# Import nessessary Libraries
#
# นำเข้า libraries ที่จำเป็น

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Q1
#
# Read data from
# https://docs.google.com/spreadsheets/d/e/2PACX-1vRIFbIywXecgxN5c1sMn_KYWsARoXgp4paFxu4qndPaX_47vRaOdrqmiHjtNZ9ZYQcv3ubMSv8DA9ta/pub?gid=0&single=true&output=csv
#
# into a dataframe named **df**
#
# จงอ่านข้อมูลจาก sheet จาก link ที่กำหนดเป็น Pandas Dataframe ชื่อ **df**

# %%
csv_data = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vRIFbIywXecgxN5c1sMn_KYWsARoXgp4paFxu4qndPaX_47vRaOdrqmiHjtNZ9ZYQcv3ubMSv8DA9ta/pub?gid=0&single=true&output=csv'
df = pd.read_csv(csv_data)
df
# Out:
#     eid      name  gender department  age  height  weight   gpa   salary  \
# 0  E011      Anda  female  developer   39     166    53.8  3.02  64200.0
# 1  E012    Bordin    male  developer   25     179    78.4  2.39  48700.0
# 2  E013  Chantana  female  developer   29     171    70.2  3.02  45500.0
# 3  E014   Donlaya  female  marketing   39     154    66.5  3.21  72600.0
# 4  E015   Ekkasit    male  marketing   37     177    66.4  3.33  80500.0
# 5  E016    Fundee  female    support   35     156    75.6  2.38  56600.0
# 6  E017   Gitiwit    male    support   26     175    69.7  3.25  42400.0
# 7  E018     Harit    male     devops   32     180    67.5  3.45  67700.0
#
#    working_years  car_park birth_place
# 0              4      True     Bangkok
# 1              2      True      Phuket
# 2              3     False    Chonburi
# 3              8     False    Chonburi
# 4              7      True  Suphanburi
# 5              3     False      Phuket
# 6              2     False  Suphanburi
# 7              5      True     Bangkok

# %% [markdown]
# ## Q2
#
# List the top-3 tallest people
#
# เลือก 3 คนแรกที่สูงที่สุด

# %%
df.sort_values(['height'], ascending=False).head(3)
# Out:
#     eid     name gender department  age  height  weight   gpa   salary  \
# 7  E018    Harit   male     devops   32     180    67.5  3.45  67700.0
# 1  E012   Bordin   male  developer   25     179    78.4  2.39  48700.0
# 4  E015  Ekkasit   male  marketing   37     177    66.4  3.33  80500.0
#
#    working_years  car_park birth_place
# 7              5      True     Bangkok
# 1              2      True      Phuket
# 4              7      True  Suphanburi

# %% [markdown]
# ## Q3
#
# The metric BMI formula = Weight (kg) ÷ Height (Metres)².
# Create a new columns named "bmi" with the bmi value
#
#
# คำนวณค่า BMI จากสมการ นำ้หนัก (kg) ÷ ส่วนสูง (Metres)²
# แล้วสร้างคอลัมน์ใหม่ ชื่อ "bmi" สำหรับค่าที่คำนวณนี้

# %%
df['bmi'] = df['weight'] / ((df['height'] / 100) ** 2)
df
# Out:
#     eid      name  gender department  age  height  weight   gpa   salary  \
# 0  E011      Anda  female  developer   39     166    53.8  3.02  64200.0
# 1  E012    Bordin    male  developer   25     179    78.4  2.39  48700.0
# 2  E013  Chantana  female  developer   29     171    70.2  3.02  45500.0
# 3  E014   Donlaya  female  marketing   39     154    66.5  3.21  72600.0
# 4  E015   Ekkasit    male  marketing   37     177    66.4  3.33  80500.0
# 5  E016    Fundee  female    support   35     156    75.6  2.38  56600.0
# 6  E017   Gitiwit    male    support   26     175    69.7  3.25  42400.0
# 7  E018     Harit    male     devops   32     180    67.5  3.45  67700.0
#
#    working_years  car_park birth_place        bmi
# 0              4      True     Bangkok  19.523879
# 1              2      True      Phuket  24.468650
# 2              3     False    Chonburi  24.007387
# 3              8     False    Chonburi  28.040142
# 4              7      True  Suphanburi  21.194421
# 5              3     False      Phuket  31.065089
# 6              2     False  Suphanburi  22.759184
# 7              5      True     Bangkok  20.833333

# %% [markdown]
# ## Q4
#
# Change the salary of Ekkasit by increasing 10%.
#
# จงเพิ่มเงินเดือนของ Ekkasit ขึ้นอีก 10%

# %%
# df.loc[4, 'salary'] = df.loc[4, 'salary'] * 110 / 100

df.loc[df['name'] == 'Ekkasit', 'salary'] *= 1.10

df
# Out:
#     eid      name  gender department  age  height  weight   gpa   salary  \
# 0  E011      Anda  female  developer   39     166    53.8  3.02  64200.0
# 1  E012    Bordin    male  developer   25     179    78.4  2.39  48700.0
# 2  E013  Chantana  female  developer   29     171    70.2  3.02  45500.0
# 3  E014   Donlaya  female  marketing   39     154    66.5  3.21  72600.0
# 4  E015   Ekkasit    male  marketing   37     177    66.4  3.33  88550.0
# 5  E016    Fundee  female    support   35     156    75.6  2.38  56600.0
# 6  E017   Gitiwit    male    support   26     175    69.7  3.25  42400.0
# 7  E018     Harit    male     devops   32     180    67.5  3.45  67700.0
#
#    working_years  car_park birth_place
# 0              4      True     Bangkok
# 1              2      True      Phuket
# 2              3     False    Chonburi
# 3              8     False    Chonburi
# 4              7      True  Suphanburi
# 5              3     False      Phuket
# 6              2     False  Suphanburi
# 7              5      True     Bangkok

# %% [markdown]
# ## Q5
#
# In crease the salary of people, who use the car park space (car_park=True) by 1000 THB.
#
# จงเพิ่มเงินเดือนให้กับผู้ที่ต้องใช้ที่จอดรถ (car_park=True) จำนวน 1000 บาท

# %%
df.loc[df['car_park'] == True, 'salary'] += 1000
df
# df['salary'] = df.apply(lambda x:  x['salary'] + 1000 if x['car_park'] == True else x['salary'], axis=1)
# Out:
#     eid      name  gender department  age  height  weight   gpa   salary  \
# 0  E011      Anda  female  developer   39     166    53.8  3.02  65200.0
# 1  E012    Bordin    male  developer   25     179    78.4  2.39  49700.0
# 2  E013  Chantana  female  developer   29     171    70.2  3.02  45500.0
# 3  E014   Donlaya  female  marketing   39     154    66.5  3.21  72600.0
# 4  E015   Ekkasit    male  marketing   37     177    66.4  3.33  89550.0
# 5  E016    Fundee  female    support   35     156    75.6  2.38  56600.0
# 6  E017   Gitiwit    male    support   26     175    69.7  3.25  42400.0
# 7  E018     Harit    male     devops   32     180    67.5  3.45  68700.0
#
#    working_years  car_park birth_place
# 0              4      True     Bangkok
# 1              2      True      Phuket
# 2              3     False    Chonburi
# 3              8     False    Chonburi
# 4              7      True  Suphanburi
# 5              3     False      Phuket
# 6              2     False  Suphanburi
# 7              5      True     Bangkok

# %% [markdown]
# ## Q6
#
# Show the average GPA grouped by department.
#
# จงแสดงค่าเฉลี่ย GPA ตามแผนก

# %%
display(df.groupby('department').agg({'gpa': 'mean'}))

display(df.groupby('department')[['gpa']].mean())

display(df.groupby('department').agg(gpa_avg=('gpa', 'mean')))
# Out:
#               gpa
# department
# developer   2.810
# devops      3.450
# marketing   3.270
# support     2.815
#               gpa
# department
# developer   2.810
# devops      3.450
# marketing   3.270
# support     2.815
#             gpa_avg
# department
# developer     2.810
# devops        3.450
# marketing     3.270
# support       2.815

# %% [markdown]
# ## Q7
#
# Show the average age of female in each department.
#
# จงหาค่าเฉลี่ยอายุของผู้หญิงในแต่ละแผนก

# %%
df[df['gender'] == 'female'].groupby('department').agg({'age': 'mean'})

df[df['gender'] == 'female'].groupby('department')[['age']].mean()
# Out:
#              age
# department
# developer   34.0
# marketing   39.0
# support     35.0

# %% [markdown]
# ## Q8
#
# Show the average age, maximum GPA, minimum GPA, and number of people in each department.
#
# จงแสดง อายุเฉลี่ย, GPA สูงสุด, GPA ต่ำสุด, และจำนวนของพนักงาน ในแต่ละแผนก

# %%
display(df.groupby('department').agg({'age': 'mean', 'gpa': ['max', 'min'], 'eid':'count'}))

df.groupby('department').agg(
    age_avg=('age', 'mean'),
    gpa_max=('gpa', 'max'),
    gpa_min=('gpa', 'min'),
    eid=('eid', 'count')
)
# Out:
#              age   gpa         eid
#             mean   max   min count
# department
# developer   31.0  3.02  2.39     3
# devops      32.0  3.45  3.45     1
# marketing   38.0  3.33  3.21     2
# support     30.5  3.25  2.38     2
#             age_avg  gpa_max  gpa_min  eid
# department
# developer      31.0     3.02     2.39    3
# devops         32.0     3.45     3.45    1
# marketing      38.0     3.33     3.21    2
# support        30.5     3.25     2.38    2

# %% [markdown]
# ## Q9
#
# Create a new column named "weight_lbs", and
# use a lambda function to calculate the weight (in kg) into lbs.
#
#
# จำสร้างคอลัมน์ใหม่ชื่อ "weight_lbs" ทีใช้ lambda function เพื่อแปลงน้ำหนักจาก กิโลกรัม เป็นหน่วย ปอนด์

# %%
df['weight_lbs'] = df['weight'].apply(lambda x: x * 2.20462)
df['weight_lbs2'] = df['weight'] * 2.20462 # fastest
df
# Out:
#     eid      name  gender department  age  height  weight   gpa   salary  \
# 0  E011      Anda  female  developer   39     166    53.8  3.02  65200.0
# 1  E012    Bordin    male  developer   25     179    78.4  2.39  49700.0
# 2  E013  Chantana  female  developer   29     171    70.2  3.02  45500.0
# 3  E014   Donlaya  female  marketing   39     154    66.5  3.21  72600.0
# 4  E015   Ekkasit    male  marketing   37     177    66.4  3.33  89550.0
# 5  E016    Fundee  female    support   35     156    75.6  2.38  56600.0
# 6  E017   Gitiwit    male    support   26     175    69.7  3.25  42400.0
# 7  E018     Harit    male     devops   32     180    67.5  3.45  68700.0
#
#    working_years  car_park birth_place  weight_lbs  weight_lbs2
# 0              4      True     Bangkok  118.608556   118.608556
# 1              2      True      Phuket  172.842208   172.842208
# 2              3     False    Chonburi  154.764324   154.764324
# 3              8     False    Chonburi  146.607230   146.607230
# 4              7      True  Suphanburi  146.386768   146.386768
# 5              3     False      Phuket  166.669272   166.669272
# 6              2     False  Suphanburi  153.662014   153.662014
# 7              5      True     Bangkok  148.811850   148.811850

# %% [markdown]
# ## Q10
#
# Create a new column named "bmi_lambda", and use a lambda function to calculate the BMI.
#
# จงสร้างคอลัมน์ใหม่ชื่อ "bmi_lambda" โดยใช้ lambda function คำนวณค่า BMI

# %%
df['bmi_lambda'] = df.apply(lambda x: x['weight'] / (x['height'] / 100) ** 2, axis=1)
df['bmi_lambda2'] = df['weight'] / (df['height'] / 100) ** 2
df
# Out:
#     eid      name  gender department  age  height  weight   gpa   salary  \
# 0  E011      Anda  female  developer   39     166    53.8  3.02  65200.0
# 1  E012    Bordin    male  developer   25     179    78.4  2.39  49700.0
# 2  E013  Chantana  female  developer   29     171    70.2  3.02  45500.0
# 3  E014   Donlaya  female  marketing   39     154    66.5  3.21  72600.0
# 4  E015   Ekkasit    male  marketing   37     177    66.4  3.33  89550.0
# 5  E016    Fundee  female    support   35     156    75.6  2.38  56600.0
# 6  E017   Gitiwit    male    support   26     175    69.7  3.25  42400.0
# 7  E018     Harit    male     devops   32     180    67.5  3.45  68700.0
#
#    working_years  car_park birth_place  weight_lbs  weight_lbs2  bmi_lambda  \
# 0              4      True     Bangkok  118.608556   118.608556   19.523879
# 1              2      True      Phuket  172.842208   172.842208   24.468650
# 2              3     False    Chonburi  154.764324   154.764324   24.007387
# 3              8     False    Chonburi  146.607230   146.607230   28.040142
# 4              7      True  Suphanburi  146.386768   146.386768   21.194421
# 5              3     False      Phuket  166.669272   166.669272   31.065089
# 6              2     False  Suphanburi  153.662014   153.662014   22.759184
# 7              5      True     Bangkok  148.811850   148.811850   20.833333
#
#    bmi_lambda2
# 0    19.523879
# 1    24.468650
# 2    24.007387
# 3    28.040142
# 4    21.194421
# 5    31.065089
# 6    22.759184
# 7    20.833333

# %% [markdown]
# ---
# https://rathachai.creatier.pro/
#
# ## つづく
