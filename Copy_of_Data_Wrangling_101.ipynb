# %% [markdown]
# <a href="https://colab.research.google.com/github/kokejohh/PMU_Module_1/blob/main/Copy_of_Data_Wrangling_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Wrangling 101**
#
# > ## *Author* : [Rathachai CHAWUTHAI](https://rathachai.creatier.pro/) , Ph.D
# > ### *Affiliation* : Computer Engineering, King Mongkut's Institute of Technology Ladkrabang (KMITL)
# > #### *Updated Date* : 2025-10-05
# ---

# %% [markdown]
# > <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.
#
#
#
# ---

# %% [markdown]
# > #### Student: Pitchakorn Thiprangsi

# %% [markdown]
# ## About Datasets

# %% [markdown]
# **Customer Churn Datasets**
#
# https://docs.google.com/spreadsheets/d/e/2PACX-1vQxcCDTAalMyu4Tc_eelskRhZXldH9TSliZLFcW39_LlzOkIReCRdK0V7JR6APjJH-EluveA5c-m237/pubhtml

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Datasets

# %%
cust_csv_path = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQxcCDTAalMyu4Tc_eelskRhZXldH9TSliZLFcW39_LlzOkIReCRdK0V7JR6APjJH-EluveA5c-m237/pub?gid=0&single=true&output=csv"
churn_csv_path = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQxcCDTAalMyu4Tc_eelskRhZXldH9TSliZLFcW39_LlzOkIReCRdK0V7JR6APjJH-EluveA5c-m237/pub?gid=755674277&single=true&output=csv"

# %%
cust_df = pd.read_csv(cust_csv_path)
churn_df = pd.read_csv(churn_csv_path)

# %%
cust_df.info()
cust_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cust_id  996 non-null    object
#  1   gender   996 non-null    object
#  2   birth    996 non-null    object
#  3   height   989 non-null    float64
#  4   weight   996 non-null    float64
#  5   address  996 non-null    object
#  6   salary   978 non-null    float64
#  7   job      958 non-null    object
#  8   payment  996 non-null    object
#  9   last_tx  996 non-null    int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 77.9+ KB
#   cust_id  gender       birth  height  weight  \
# 0  C-0001    male  06/02/1958  175.03   72.63
# 1  C-0002    male  09/06/1987  171.75   71.08
# 2  C-0003  female  07/02/1997  166.86   56.34
# 3  C-0004  female  06/10/1983  166.73   64.46
# 4  C-0005    male  02/17/1983  171.24   61.25
#
#                              address   salary      job payment  last_tx
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90

# %%
churn_df.info()
churn_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cust_id  900 non-null    object
#  1   churn    900 non-null    object
# dtypes: object(2)
# memory usage: 14.2+ KB
#   cust_id  churn
# 0  C-0002  churn
# 1  C-0006  churn
# 2  C-0009  churn
# 3  C-0015  churn
# 4  C-0016  churn

# %% [markdown]
# ## Merge Datasets

# %%
df = pd.merge(cust_df, churn_df, how='left', on='cust_id')
# df = pd.merge(cust_df, churn_df, how='left', left_on='cust_id', right_on='cust_id')

# %%
df.head()
# Out:
#   cust_id  gender       birth  height  weight  \
# 0  C-0001    male  06/02/1958  175.03   72.63
# 1  C-0002    male  09/06/1987  171.75   71.08
# 2  C-0003  female  07/02/1997  166.86   56.34
# 3  C-0004  female  06/10/1983  166.73   64.46
# 4  C-0005    male  02/17/1983  171.24   61.25
#
#                              address   salary      job payment  last_tx  churn
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98  loyal
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118  churn
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107  loyal
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177    NaN
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90  loyal

# %% [markdown]
# ## Drop Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cust_id  996 non-null    object
#  1   gender   996 non-null    object
#  2   birth    996 non-null    object
#  3   height   989 non-null    float64
#  4   weight   996 non-null    float64
#  5   address  996 non-null    object
#  6   salary   978 non-null    float64
#  7   job      958 non-null    object
#  8   payment  996 non-null    object
#  9   last_tx  996 non-null    int64
#  10  churn    900 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 85.7+ KB

# %%
df['churn'] = df['churn'].fillna('unknown') # fill unknown insteads drop rows

# %%
# df.dropna(subset=['churn'], inplace=True)

# %%
df.head()
# Out:
#   cust_id  gender       birth  height  weight  \
# 0  C-0001    male  06/02/1958  175.03   72.63
# 1  C-0002    male  09/06/1987  171.75   71.08
# 2  C-0003  female  07/02/1997  166.86   56.34
# 3  C-0004  female  06/10/1983  166.73   64.46
# 4  C-0005    male  02/17/1983  171.24   61.25
#
#                              address   salary      job payment  last_tx  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
#
#      churn
# 0    loyal
# 1    churn
# 2    loyal
# 3  unknown
# 4    loyal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cust_id  996 non-null    object
#  1   gender   996 non-null    object
#  2   birth    996 non-null    object
#  3   height   989 non-null    float64
#  4   weight   996 non-null    float64
#  5   address  996 non-null    object
#  6   salary   978 non-null    float64
#  7   job      958 non-null    object
#  8   payment  996 non-null    object
#  9   last_tx  996 non-null    int64
#  10  churn    996 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 85.7+ KB

# %% [markdown]
# ## Cap the Outliners

# %%
df.boxplot(column=['height'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['weight'])
# Out:
# <Axes: >

# %%
df.dropna().sort_values('height')[['height']].plot.bar(use_index=False, figsize=(10, 3),xticks=[], xlim=(0, 1200), ylim=(100, 500))
# Out:
# <Axes: >

# %%
low, high = df["height"].quantile([0.05, 0.95])
print(low, high)
# Out:
# 151.87 179.196

# %%
df.loc[df['height'] < low, 'height'] = low
df.head()
# Out:
#   cust_id  gender       birth  height  weight  \
# 0  C-0001    male  06/02/1958  175.03   72.63
# 1  C-0002    male  09/06/1987  171.75   71.08
# 2  C-0003  female  07/02/1997  166.86   56.34
# 3  C-0004  female  06/10/1983  166.73   64.46
# 4  C-0005    male  02/17/1983  171.24   61.25
#
#                              address   salary      job payment  last_tx  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
#
#      churn
# 0    loyal
# 1    churn
# 2    loyal
# 3  unknown
# 4    loyal

# %%
df.loc[df['height'] > high, 'height'] = high

# %%
df.head()
# Out:
#   cust_id  gender       birth  height  weight  \
# 0  C-0001    male  06/02/1958  175.03   72.63
# 1  C-0002    male  09/06/1987  171.75   71.08
# 2  C-0003  female  07/02/1997  166.86   56.34
# 3  C-0004  female  06/10/1983  166.73   64.46
# 4  C-0005    male  02/17/1983  171.24   61.25
#
#                              address   salary      job payment  last_tx  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
#
#      churn
# 0    loyal
# 1    churn
# 2    loyal
# 3  unknown
# 4    loyal

# %%
df.boxplot(column='height')
# Out:
# <Axes: >

# %% [markdown]
# **Quiz !!**
#
# > ลอง cap ที่ percentile 10-90

# %%
# Answer
low, high = df['height'].quantile([0.1, 0.9])
print(low, high)

# df.loc[df['height'] < low, 'height'] = low
# df.loc[df['height'] < high, 'height'] = high
# Out:
# 153.898 176.982

# %% [markdown]
# ## Infer Missing Values (I)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cust_id  996 non-null    object
#  1   gender   996 non-null    object
#  2   birth    996 non-null    object
#  3   height   989 non-null    float64
#  4   weight   996 non-null    float64
#  5   address  996 non-null    object
#  6   salary   978 non-null    float64
#  7   job      958 non-null    object
#  8   payment  996 non-null    object
#  9   last_tx  996 non-null    int64
#  10  churn    996 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 85.7+ KB

# %%
df.sort_values("height")
# Out:
#     cust_id  gender       birth  height  weight  \
# 913  C-0914  female  01/10/1976  151.87   47.98
# 931  C-0932  female  04/16/1979  151.87   45.23
# 930  C-0931  female  05/16/1953  151.87   44.09
# 965  C-0966  female  07/05/1984  151.87   49.79
# 852  C-0853  female  09/04/1996  151.87   43.08
# ..      ...     ...         ...     ...     ...
# 331  C-0332    male  09/24/1976     NaN   66.42
# 602  C-0603    male  06/05/1981     NaN   69.17
# 697  C-0698  female  02/04/1970     NaN   65.64
# 818  C-0819    male  03/12/1932     NaN   73.65
# 881  C-0882    male  06/06/1978     NaN   80.31
#
#                                  address    salary      job payment  last_tx  \
# 913        339/54, บางเสาธง, สมุทรปราการ  109522.0   worker  credit       87
# 931         248/37, บางขุนเทียน, กรุงเทพ   92156.0   worker    cash      123
# 930             295/25, กำแพงแสน, นครปฐม   26071.0  retired  cheque       93
# 965          360/35, บางพลี, สมุทรปราการ   66595.0   worker  credit      130
# 852              294/9, ปทุมวัน, กรุงเทพ   29211.0   worker  credit       21
# ..                                   ...       ...      ...     ...      ...
# 331        394/50, เมืองนนทบุรี, นนทบุรี  108990.0   worker    cash      192
# 602              463/33, สายไหม, กรุงเทพ   81106.0   worker  credit       85
# 697             279/64, บึงกุ่ม, กรุงเทพ  153150.0   worker  credit      139
# 818  213/28, พระสมุทรเจดีย์, สมุทรปราการ   26914.0  retired  credit      123
# 881          351/58, บางกอกใหญ่, กรุงเทพ   96096.0   worker  credit       83
#
#        churn
# 913    loyal
# 931    churn
# 930    churn
# 965    churn
# 852    loyal
# ..       ...
# 331    churn
# 602    loyal
# 697    churn
# 818    loyal
# 881  unknown
#
# [996 rows x 11 columns]

# %%
df.sort_values("height", inplace=True)

# %%
df["height"].fillna(df["height"].median())
# Out:
# 0      175.03
# 1      171.75
# 2      166.86
# 3      166.73
# 4      171.24
#         ...
# 991    170.93
# 992    177.95
# 993    160.77
# 994    168.71
# 995    152.80
# Name: height, Length: 996, dtype: float64

# %%
df.boxplot(column="height")
# Out:
# <Axes: >

# %%
df.boxplot(column='height', by='gender')
# Out:
# <Axes: title={'center': 'height'}, xlabel='gender'>

# %%
# Recommended !!!!
df['height'] = df['height'].fillna(df.groupby('gender')['height'].transform('mean'))
df.head()
# Out:
#   cust_id  gender       birth  height  weight  \
# 0  C-0001    male  06/02/1958  175.03   72.63
# 1  C-0002    male  09/06/1987  171.75   71.08
# 2  C-0003  female  07/02/1997  166.86   56.34
# 3  C-0004  female  06/10/1983  166.73   64.46
# 4  C-0005    male  02/17/1983  171.24   61.25
#
#                              address   salary      job payment  last_tx  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
#
#      churn
# 0    loyal
# 1    churn
# 2    loyal
# 3  unknown
# 4    loyal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cust_id  996 non-null    object
#  1   gender   996 non-null    object
#  2   birth    996 non-null    object
#  3   height   996 non-null    float64
#  4   weight   996 non-null    float64
#  5   address  996 non-null    object
#  6   salary   978 non-null    float64
#  7   job      958 non-null    object
#  8   payment  996 non-null    object
#  9   last_tx  996 non-null    int64
#  10  churn    996 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 85.7+ KB

# %% [markdown]
# ## Extract Date Time

# %%
df["birth"]
# Out:
# 0      06/02/1958
# 1      09/06/1987
# 2      07/02/1997
# 3      06/10/1983
# 4      02/17/1983
#           ...
# 991    03/02/1993
# 992    04/07/1938
# 993    04/27/2002
# 994    02/27/2003
# 995    04/28/1998
# Name: birth, Length: 996, dtype: object

# %%
df['birth'] = pd.to_datetime(df['birth'], format='%m/%d/%Y')

# %%
df["birth"]
# Out:
# 0     1958-06-02
# 1     1987-09-06
# 2     1997-07-02
# 3     1983-06-10
# 4     1983-02-17
#          ...
# 991   1993-03-02
# 992   1938-04-07
# 993   2002-04-27
# 994   2003-02-27
# 995   1998-04-28
# Name: birth, Length: 996, dtype: datetime64[ns]

# %%
2025 - df["birth"].dt.year
# Out:
# 0      67
# 1      38
# 2      28
# 3      42
# 4      42
#        ..
# 991    32
# 992    87
# 993    23
# 994    22
# 995    27
# Name: birth, Length: 996, dtype: int32

# %%
df['age'] = 2025 - df['birth'].dt.year

# %%
df
# Out:
#     cust_id  gender      birth  height  weight  \
# 0    C-0001    male 1958-06-02  175.03   72.63
# 1    C-0002    male 1987-09-06  171.75   71.08
# 2    C-0003  female 1997-07-02  166.86   56.34
# 3    C-0004  female 1983-06-10  166.73   64.46
# 4    C-0005    male 1983-02-17  171.24   61.25
# ..      ...     ...        ...     ...     ...
# 991  C-0992  female 1993-03-02  170.93   60.82
# 992  C-0993    male 1938-04-07  177.95   69.24
# 993  C-0994    male 2002-04-27  160.77   56.95
# 994  C-0995    male 2003-02-27  168.71   67.65
# 995  C-0996  female 1998-04-28  152.80   51.05
#
#                                address   salary      job payment  last_tx  \
# 0             140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1    198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2             379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3              361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4           132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
# ..                                 ...      ...      ...     ...      ...
# 991          161/10, ลาดพร้าว, กรุงเทพ  36333.0   worker  credit       33
# 992      158/61, กระทุ่มแบน, สมุทรสาคร  43782.0  retired  credit      124
# 993         418/5, บ้านแพ้ว, สมุทรสาคร  19737.0   worker  credit       60
# 994          276/51, บึ่งกุ่ม, กรุงเทพ   6693.0  student  credit       49
# 995           23/61, ทวีวัฒนา, กรุงเทพ  26580.0   worker  credit       25
#
#        churn  age
# 0      loyal   67
# 1      churn   38
# 2      loyal   28
# 3    unknown   42
# 4      loyal   42
# ..       ...  ...
# 991    loyal   32
# 992    loyal   87
# 993  unknown   23
# 994    loyal   22
# 995    loyal   27
#
# [996 rows x 12 columns]

# %% [markdown]
# **Quiz !!**
#
# > สร้างคอลัมน์ birth_dow เพื่อแสดงวันเกิดในสัปดาห์ sun, mon, tue, wed, thu, fri, sat

# %%
# days = ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']
# df['birth_dow'] = df['birth'].dt.day_of_week.apply(lambda x: days[x])
# df['birth_dow'] = df['birth'].dt.day_name()
df['birth_dow'] = df['birth'].dt.strftime('%A')
df
# Out:
#     cust_id  gender      birth  height  weight  \
# 0    C-0001    male 1958-06-02  175.03   72.63
# 1    C-0002    male 1987-09-06  171.75   71.08
# 2    C-0003  female 1997-07-02  166.86   56.34
# 3    C-0004  female 1983-06-10  166.73   64.46
# 4    C-0005    male 1983-02-17  171.24   61.25
# ..      ...     ...        ...     ...     ...
# 991  C-0992  female 1993-03-02  170.93   60.82
# 992  C-0993    male 1938-04-07  177.95   69.24
# 993  C-0994    male 2002-04-27  160.77   56.95
# 994  C-0995    male 2003-02-27  168.71   67.65
# 995  C-0996  female 1998-04-28  152.80   51.05
#
#                                address   salary      job payment  last_tx  \
# 0             140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1    198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2             379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3              361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4           132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
# ..                                 ...      ...      ...     ...      ...
# 991          161/10, ลาดพร้าว, กรุงเทพ  36333.0   worker  credit       33
# 992      158/61, กระทุ่มแบน, สมุทรสาคร  43782.0  retired  credit      124
# 993         418/5, บ้านแพ้ว, สมุทรสาคร  19737.0   worker  credit       60
# 994          276/51, บึ่งกุ่ม, กรุงเทพ   6693.0  student  credit       49
# 995           23/61, ทวีวัฒนา, กรุงเทพ  26580.0   worker  credit       25
#
#        churn  age  birth_dow
# 0      loyal   67     Monday
# 1      churn   38     Sunday
# 2      loyal   28  Wednesday
# 3    unknown   42     Friday
# 4      loyal   42   Thursday
# ..       ...  ...        ...
# 991    loyal   32    Tuesday
# 992    loyal   87   Thursday
# 993  unknown   23   Saturday
# 994    loyal   22   Thursday
# 995    loyal   27    Tuesday
#
# [996 rows x 13 columns]

# %% [markdown]
# ## Bining

# %%
df["age"].hist()
# Out:
# <Axes: >

# %%
cut_labels = ['young', 'teen', 'adult', 'senior']
cut_bins = [0, 13, 25, 61, 100]
df['age_group'] = pd.cut(df['age'], bins=cut_bins, labels=cut_labels)

# %%
df.head()
# Out:
#   cust_id  gender      birth  height  weight  \
# 0  C-0001    male 1958-06-02  175.03   72.63
# 1  C-0002    male 1987-09-06  171.75   71.08
# 2  C-0003  female 1997-07-02  166.86   56.34
# 3  C-0004  female 1983-06-10  166.73   64.46
# 4  C-0005    male 1983-02-17  171.24   61.25
#
#                              address   salary      job payment  last_tx  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
#
#      churn  age  birth_dow age_group
# 0    loyal   67     Monday    senior
# 1    churn   38     Sunday     adult
# 2    loyal   28  Wednesday     adult
# 3  unknown   42     Friday     adult
# 4    loyal   42   Thursday     adult

# %%
df.boxplot(column='age', by='age_group')
df.groupby('age_group', observed=False)[['age']].count().plot.bar()
# Out:
# <Axes: xlabel='age_group'>

# %%
df.boxplot(column='salary', by='age_group')
# Out:
# <Axes: title={'center': 'salary'}, xlabel='age_group'>

# %% [markdown]
# **Quiz !!**
#
# > ทดลองทำ binning ของกลุ่มเงินเดือน Low (น้อยกว่า 50,000), Med (50,000 - 100,000), High (มากกว่า 100,000)

# %%
cut_bins = [0, 50000, 100000, 1000000]
cut_labels = ['low', 'med', 'high']

df['salary_group'] = pd.cut(df['salary'], bins=cut_bins, labels=cut_labels)
df.head()
# Out:
#   cust_id  gender      birth  height  weight  \
# 0  C-0001    male 1958-06-02  175.03   72.63
# 1  C-0002    male 1987-09-06  171.75   71.08
# 2  C-0003  female 1997-07-02  166.86   56.34
# 3  C-0004  female 1983-06-10  166.73   64.46
# 4  C-0005    male 1983-02-17  171.24   61.25
#
#                              address   salary      job payment  last_tx  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
#
#      churn  age  birth_dow age_group salary_group
# 0    loyal   67     Monday    senior          low
# 1    churn   38     Sunday     adult          med
# 2    loyal   28  Wednesday     adult          low
# 3  unknown   42     Friday     adult          med
# 4    loyal   42   Thursday     adult          med

# %% [markdown]
# ## Log Scale

# %%
df[df['job'] == 'worker']['salary'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['job']=='worker'].plot.scatter(x='age', y='salary')
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
# df["salary_log"] = df["salary"].apply(np.log)
df['salary_log'] = np.log(df['salary'])

# %%
df[df['job']=='worker'].plot.scatter(x='age',y='salary_log')
# Out:
# <Axes: xlabel='age', ylabel='salary_log'>

# %%
df[df['job'] == 'worker']['salary_log'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Binary Encoding

# %%
df[['gender']]
# Out:
#      gender
# 0      male
# 1      male
# 2    female
# 3    female
# 4      male
# ..      ...
# 991  female
# 992    male
# 993    male
# 994    male
# 995  female
#
# [996 rows x 1 columns]

# %%
df['gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
df['gender_code'] = lb_make.fit_transform(df['gender'])
# lb_make.classes_
df.head()
# Out:
#   cust_id  gender      birth  height  weight  \
# 0  C-0001    male 1958-06-02  175.03   72.63
# 1  C-0002    male 1987-09-06  171.75   71.08
# 2  C-0003  female 1997-07-02  166.86   56.34
# 3  C-0004  female 1983-06-10  166.73   64.46
# 4  C-0005    male 1983-02-17  171.24   61.25
#
#                              address   salary      job payment  last_tx  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
#
#      churn  age  birth_dow age_group salary_group  salary_log  gender_code
# 0    loyal   67     Monday    senior          low   10.124308            1
# 1    churn   38     Sunday     adult          med   10.917522            1
# 2    loyal   28  Wednesday     adult          low   10.206662            0
# 3  unknown   42     Friday     adult          med   11.175086            0
# 4    loyal   42   Thursday     adult          med   11.182670            1

# %% [markdown]
# **Quiz !!**
#
# > ทำ label encoding ของ payment

# %%
from sklearn.preprocessing import LabelEncoder
print(df['payment'].unique())
lb_make = LabelEncoder()
df['payment_code'] = lb_make.fit_transform(df['payment'])
df.head()
# Out:
# ['credit' 'cheque' 'cash']
#   cust_id  gender      birth  height  weight  \
# 0  C-0001    male 1958-06-02  175.03   72.63
# 1  C-0002    male 1987-09-06  171.75   71.08
# 2  C-0003  female 1997-07-02  166.86   56.34
# 3  C-0004  female 1983-06-10  166.73   64.46
# 4  C-0005    male 1983-02-17  171.24   61.25
#
#                              address   salary      job payment  last_tx  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired  credit       98
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker  cheque      118
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker  credit      107
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker  credit      177
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker  credit       90
#
#      churn  age  birth_dow age_group salary_group  salary_log  gender_code  \
# 0    loyal   67     Monday    senior          low   10.124308            1
# 1    churn   38     Sunday     adult          med   10.917522            1
# 2    loyal   28  Wednesday     adult          low   10.206662            0
# 3  unknown   42     Friday     adult          med   11.175086            0
# 4    loyal   42   Thursday     adult          med   11.182670            1
#
#    payment_code
# 0             2
# 1             1
# 2             2
# 3             2
# 4             2

# %% [markdown]
# ## One-Hot Encoding

# %%
df[['payment']]
# Out:
#     payment
# 0    credit
# 1    cheque
# 2    credit
# 3    credit
# 4    credit
# ..      ...
# 991  credit
# 992  credit
# 993  credit
# 994  credit
# 995  credit
#
# [996 rows x 1 columns]

# %%
df['payment'].unique()
# Out:
# array(['credit', 'cheque', 'cash'], dtype=object)

# %%
df = pd.get_dummies(df, columns=['payment'])

# %%
df.head()
# Out:
#   cust_id  gender      birth  height  weight  \
# 0  C-0001    male 1958-06-02  175.03   72.63
# 1  C-0002    male 1987-09-06  171.75   71.08
# 2  C-0003  female 1997-07-02  166.86   56.34
# 3  C-0004  female 1983-06-10  166.73   64.46
# 4  C-0005    male 1983-02-17  171.24   61.25
#
#                              address   salary      job  last_tx    churn  age  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired       98    loyal   67
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker      118    churn   38
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker      107    loyal   28
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker      177  unknown   42
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker       90    loyal   42
#
#    birth_dow age_group salary_group  salary_log  gender_code  payment_code  \
# 0     Monday    senior          low   10.124308            1             2
# 1     Sunday     adult          med   10.917522            1             1
# 2  Wednesday     adult          low   10.206662            0             2
# 3     Friday     adult          med   11.175086            0             2
# 4   Thursday     adult          med   11.182670            1             2
#
#    payment_cash  payment_cheque  payment_credit
# 0         False           False            True
# 1         False            True           False
# 2         False           False            True
# 3         False           False            True
# 4         False           False            True

# %%
df[['payment_cash', 'payment_cheque', 'payment_credit']]
# Out:
#      payment_cash  payment_cheque  payment_credit
# 0           False           False            True
# 1           False            True           False
# 2           False           False            True
# 3           False           False            True
# 4           False           False            True
# ..            ...             ...             ...
# 991         False           False            True
# 992         False           False            True
# 993         False           False            True
# 994         False           False            True
# 995         False           False            True
#
# [996 rows x 3 columns]

# %% [markdown]
# **Quiz !!**
#
# > ทำ One-Hot encoding ของ birth_dow

# %%
# Answer
df2 = pd.get_dummies(df, columns=['birth_dow'])
df2.head()
# Out:
#   cust_id  gender      birth  height  weight  \
# 0  C-0001    male 1958-06-02  175.03   72.63
# 1  C-0002    male 1987-09-06  171.75   71.08
# 2  C-0003  female 1997-07-02  166.86   56.34
# 3  C-0004  female 1983-06-10  166.73   64.46
# 4  C-0005    male 1983-02-17  171.24   61.25
#
#                              address   salary      job  last_tx    churn  ...  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired       98    loyal  ...
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker      118    churn  ...
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker      107    loyal  ...
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker      177  unknown  ...
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker       90    loyal  ...
#
#    payment_cash payment_cheque payment_credit  birth_dow_Friday  \
# 0         False          False           True             False
# 1         False           True          False             False
# 2         False          False           True             False
# 3         False          False           True              True
# 4         False          False           True             False
#
#    birth_dow_Monday  birth_dow_Saturday  birth_dow_Sunday  birth_dow_Thursday  \
# 0              True               False             False               False
# 1             False               False              True               False
# 2             False               False             False               False
# 3             False               False             False               False
# 4             False               False             False                True
#
#    birth_dow_Tuesday  birth_dow_Wednesday
# 0              False                False
# 1              False                False
# 2              False                 True
# 3              False                False
# 4              False                False
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Text Extraction

# %%
df[['address']]
# Out:
#                                address
# 0             140/27, ทุ่งครุ, กรุงเทพ
# 1    198/57, เมืองสมุทรสาคร, สมุทรสาคร
# 2             379/22, คลองเตย, กรุงเทพ
# 3              361/6, บางกรวย, นนทบุรี
# 4           132/13, คลองหลวง, ปทุมธานี
# ..                                 ...
# 991          161/10, ลาดพร้าว, กรุงเทพ
# 992      158/61, กระทุ่มแบน, สมุทรสาคร
# 993         418/5, บ้านแพ้ว, สมุทรสาคร
# 994          276/51, บึ่งกุ่ม, กรุงเทพ
# 995           23/61, ทวีวัฒนา, กรุงเทพ
#
# [996 rows x 1 columns]

# %%
# "14/24, ปทุมวัน, กรุงเทพ".split(', ')
# '14/24, phathumwan, bangkok'.replace(' ', '').split(',')
# ''.join('14/24, phathumwan, bangkok'.split()).split(',')

import re
re.split(r'\s*,\s*', '14/24, phatuhu mwan,   bangkok')
# Out:
# ['14/24', 'phatuhu mwan', 'bangkok']

# %%
# "14/24, ปทุมวัน, กรุงเทพ".split(", ")[-1]
import re
re.split(r'\s*,\s*', '14/24, phathumwan, bangkok')[-1]
# Out:
# 'bangkok'

# %%
# df["address"].str.split(", ").str[-1]
# df['address'].apply(lambda x: re.split(r'\s*,\s*', x)[-1])
df['address'].str.split(r'\s*,\s*', regex=True).str[-1]
# Out:
# 0        กรุงเทพ
# 1      สมุทรสาคร
# 2        กรุงเทพ
# 3        นนทบุรี
# 4       ปทุมธานี
#          ...
# 991      กรุงเทพ
# 992    สมุทรสาคร
# 993    สมุทรสาคร
# 994      กรุงเทพ
# 995      กรุงเทพ
# Name: address, Length: 996, dtype: object

# %%
df['city'] = df['address'].str.split(r'\s*,\s*', regex=True).str[-1]

# %%
df.head()
# Out:
#   cust_id  gender      birth  height  weight  \
# 0  C-0001    male 1958-06-02  175.03   72.63
# 1  C-0002    male 1987-09-06  171.75   71.08
# 2  C-0003  female 1997-07-02  166.86   56.34
# 3  C-0004  female 1983-06-10  166.73   64.46
# 4  C-0005    male 1983-02-17  171.24   61.25
#
#                              address   salary      job  last_tx    churn  ...  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired       98    loyal  ...
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker      118    churn  ...
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker      107    loyal  ...
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker      177  unknown  ...
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker       90    loyal  ...
#
#    birth_dow age_group salary_group salary_log  gender_code  payment_code  \
# 0     Monday    senior          low  10.124308            1             2
# 1     Sunday     adult          med  10.917522            1             1
# 2  Wednesday     adult          low  10.206662            0             2
# 3     Friday     adult          med  11.175086            0             2
# 4   Thursday     adult          med  11.182670            1             2
#
#    payment_cash  payment_cheque  payment_credit       city
# 0         False           False            True    กรุงเทพ
# 1         False            True           False  สมุทรสาคร
# 2         False           False            True    กรุงเทพ
# 3         False           False            True    นนทบุรี
# 4         False           False            True   ปทุมธานี
#
# [5 rows x 21 columns]

# %% [markdown]
# **Quiz !!**
#
# > ดึงค่าอำเภอ/เขต มาใส่คอลัมน์ district

# %%
df['district'] = df['address'].str.split(r'\s*,\s', regex=True).str[-2]

# %%
df.head()
# Out:
#   cust_id  gender      birth  height  weight  \
# 0  C-0001    male 1958-06-02  175.03   72.63
# 1  C-0002    male 1987-09-06  171.75   71.08
# 2  C-0003  female 1997-07-02  166.86   56.34
# 3  C-0004  female 1983-06-10  166.73   64.46
# 4  C-0005    male 1983-02-17  171.24   61.25
#
#                              address   salary      job  last_tx    churn  ...  \
# 0           140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired       98    loyal  ...
# 1  198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker      118    churn  ...
# 2           379/22, คลองเตย, กรุงเทพ  27083.0   worker      107    loyal  ...
# 3            361/6, บางกรวย, นนทบุรี  71331.0   worker      177  unknown  ...
# 4         132/13, คลองหลวง, ปทุมธานี  71874.0   worker       90    loyal  ...
#
#    age_group salary_group salary_log gender_code  payment_code  payment_cash  \
# 0     senior          low  10.124308           1             2         False
# 1      adult          med  10.917522           1             1         False
# 2      adult          low  10.206662           0             2         False
# 3      adult          med  11.175086           0             2         False
# 4      adult          med  11.182670           1             2         False
#
#    payment_cheque  payment_credit       city        district
# 0           False            True    กรุงเทพ         ทุ่งครุ
# 1            True           False  สมุทรสาคร  เมืองสมุทรสาคร
# 2           False            True    กรุงเทพ         คลองเตย
# 3           False            True    นนทบุรี         บางกรวย
# 4           False            True   ปทุมธานี        คลองหลวง
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Charts

# %%
import matplotlib.pyplot as plt
df
# Out:
#     cust_id  gender      birth  height  weight  \
# 0    C-0001    male 1958-06-02  175.03   72.63
# 1    C-0002    male 1987-09-06  171.75   71.08
# 2    C-0003  female 1997-07-02  166.86   56.34
# 3    C-0004  female 1983-06-10  166.73   64.46
# 4    C-0005    male 1983-02-17  171.24   61.25
# ..      ...     ...        ...     ...     ...
# 991  C-0992  female 1993-03-02  170.93   60.82
# 992  C-0993    male 1938-04-07  177.95   69.24
# 993  C-0994    male 2002-04-27  160.77   56.95
# 994  C-0995    male 2003-02-27  168.71   67.65
# 995  C-0996  female 1998-04-28  152.80   51.05
#
#                                address   salary      job  last_tx    churn  \
# 0             140/27, ทุ่งครุ, กรุงเทพ  24942.0  retired       98    loyal
# 1    198/57, เมืองสมุทรสาคร, สมุทรสาคร  55134.0   worker      118    churn
# 2             379/22, คลองเตย, กรุงเทพ  27083.0   worker      107    loyal
# 3              361/6, บางกรวย, นนทบุรี  71331.0   worker      177  unknown
# 4           132/13, คลองหลวง, ปทุมธานี  71874.0   worker       90    loyal
# ..                                 ...      ...      ...      ...      ...
# 991          161/10, ลาดพร้าว, กรุงเทพ  36333.0   worker       33    loyal
# 992      158/61, กระทุ่มแบน, สมุทรสาคร  43782.0  retired      124    loyal
# 993         418/5, บ้านแพ้ว, สมุทรสาคร  19737.0   worker       60  unknown
# 994          276/51, บึ่งกุ่ม, กรุงเทพ   6693.0  student       49    loyal
# 995           23/61, ทวีวัฒนา, กรุงเทพ  26580.0   worker       25    loyal
#
#      ...  age_group salary_group salary_log gender_code  payment_code  \
# 0    ...     senior          low  10.124308           1             2
# 1    ...      adult          med  10.917522           1             1
# 2    ...      adult          low  10.206662           0             2
# 3    ...      adult          med  11.175086           0             2
# 4    ...      adult          med  11.182670           1             2
# ..   ...        ...          ...        ...         ...           ...
# 991  ...      adult          low  10.500482           0             2
# 992  ...     senior          low  10.686978           1             2
# 993  ...       teen          low   9.890250           1             2
# 994  ...       teen          low   8.808817           1             2
# 995  ...      adult          low  10.187914           0             2
#
#      payment_cash  payment_cheque  payment_credit       city        district
# 0           False           False            True    กรุงเทพ         ทุ่งครุ
# 1           False            True           False  สมุทรสาคร  เมืองสมุทรสาคร
# 2           False           False            True    กรุงเทพ         คลองเตย
# 3           False           False            True    นนทบุรี         บางกรวย
# 4           False           False            True   ปทุมธานี        คลองหลวง
# ..            ...             ...             ...        ...             ...
# 991         False           False            True    กรุงเทพ        ลาดพร้าว
# 992         False           False            True  สมุทรสาคร      กระทุ่มแบน
# 993         False           False            True  สมุทรสาคร        บ้านแพ้ว
# 994         False           False            True    กรุงเทพ        บึ่งกุ่ม
# 995         False           False            True    กรุงเทพ        ทวีวัฒนา
#
# [996 rows x 22 columns]

# %% [markdown]
# ### Line Chart

# %%
df.groupby('age')[['salary']].mean()
# Out:
#            salary
# age
# 20   18938.038462
# 21   20675.416667
# 22   17131.058824
# 23   15391.850000
# 24   18285.100000
# ..            ...
# 89   24642.750000
# 90   29332.500000
# 92   38931.200000
# 93   29328.714286
# 94   28448.500000
#
# [74 rows x 1 columns]

# %%
# df.groupby('age')[['salary']].mean().plot()
# 2. Plot using plt
salary_by_age = df.group
plt.figure(figsize=(8,5))
plt.plot(salary_by_age.index, salary_by_age.values, marker='o')
plt.xlabel('Age')
plt.ylabel('Average Salary')
plt.title('Average Salary by Age')
plt.grid(True)
plt.show()
# Out:
# <Axes: xlabel='age'>

# %%
df.groupby('age')[['salary']].agg(['max', 'mean', 'min']).plot()
df.groupby('age')[['salary']].agg(['max', 'mean', 'min']).plot()
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# **Quiz !!**
#
# > สร้าง line chart ที่มีแกน x เป็นอายุ และ แกน y เป็นค่าสูงสุดของส่วนสูง

# %%
# Answer
df.groupby('age')[['height']].agg(['max']).plot()
df.groupby('age')[['height']].agg('max').plot()
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ### Bar Charts

# %%
df.groupby('job')[['salary']].mean()
df.groupby('job')[['salary']].mean()
# Out:
#                salary
# job
# retired  32275.973118
# student  18671.280374
# worker   95130.728242

# %%
df.groupby('age_group')[['salary']].mean().plot.bar()
# Out:
# /tmp/ipython-input-2479823778.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')[['salary']].mean().plot.bar()
# <Axes: xlabel='age_group'>

# %%
df.groupby('age_group')[['salary']].mean().plot.barh()
df.groupby('age_group')[['salary']].mean().plot.barh()
# Out:
# /tmp/ipython-input-501010877.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')[['salary']].mean().plot.barh()
# /tmp/ipython-input-501010877.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')[['salary']].mean().plot.barh()
# <Axes: ylabel='age_group'>

# %%
df.groupby('age_group')[['salary']].agg(['max', 'mean', 'min']).plot.barh()



df.groupby('age_group')[['salary']].agg(['min', 'max', 'mean']).plot.barh()
# Out:
# /tmp/ipython-input-1858016752.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')[['salary']].agg(['max', 'mean', 'min']).plot.barh()
# /tmp/ipython-input-1858016752.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')[['salary']].agg(['min', 'max', 'mean']).plot.barh()
# <Axes: ylabel='age_group'>

# %% [markdown]
# **Quiz !!**
#
# > สร้าง horizontal bar chart แสดงค่าเฉลี่ยของ salary ของแต่ละ job

# %%
# Answer
df.groupby('job')[['salary']].agg(['mean']).sort_values(('salary', 'mean')).plot.barh()
# Out:
# <Axes: ylabel='job'>

# %% [markdown]
# ### Pie Charts

# %%
df.groupby('gender')['cust_id'].count()
# Out:
# gender
# female    407
# male      493
# Name: cust_id, dtype: int64

# %%
df.groupby('gender')['cust_id'].count().plot.pie()
# Out:
# <Axes: ylabel='cust_id'>

# %%
df.groupby(['churn']).agg({'cust_id':'count', 'age':'mean'}).plot.pie(subplots=True)
# Out:
# array([<Axes: ylabel='cust_id'>, <Axes: ylabel='age'>], dtype=object)

# %% [markdown]
# **Quiz !!**
#
# > สร้าง pie chart แสดงจำนวนลูกค้า ในแต่ละประเภทของ job

# %%
# Answer
# df.groupby(['job']).agg({'cust_id': 'count'}).plot.pie(subplots=True)

df.groupby('job').agg({'cust_id': 'count'})#.plot.pie(subplots=True)
df.groupby('job')['cust_id'].agg(['count'])#.plot.pie(subplots=True)
# df.groupby('job')['cust_id'].count().plot.pie()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2811663323.py in <cell line: 0>()
#       5 df.groupby('job')['cust_id'].agg(['count'])#.plot.pie(subplots=True)
#       6 # df.groupby('job')['cust_id'].count().plot.pie()
# ----> 7 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Histogram

# %%
df['salary'].hist()
# Out:
# <Axes: >

# %%
df['salary'].hist(bins=20)

df['salary'].hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# **Quiz !!**
#
# > สร้าง histogram ของ age ที่มีค่า 10 ช่วง

# %%
# Answer
df['age'].hist(bins=10)
# Out:
# <Axes: >

# %% [markdown]
# ### Box Plots

# %%
df[['height']].boxplot()
# Out:
# <Axes: >

# %%
df[['height', 'age']].boxplot()
# Out:
# <Axes: >

# %%
df.boxplot(column="salary", by="age_group")
# Out:
# <Axes: title={'center': 'salary'}, xlabel='age_group'>

# %% [markdown]
# **Quiz !!**
#
# > แสดง Box Plot ของอายุ ตามกลุ่ม churn

# %%
df.boxplot(column='age', by='churn')
# Out:
# <Axes: title={'center': 'age'}, xlabel='churn'>

# %% [markdown]
# ### Scatter Plot

# %%
df[(df['age']>25) & (df['age']<40)].plot.scatter(x='age',y='salary')
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %% [markdown]
# **Quiz !!**
#
# > แสดง Scatter Plot ระหว่าง weight และ height ของ job ที่เป็น student

# %%
# Answer
df[(df['job'] == 'student')].plot.scatter(x='weight', y='height')
# Out:
# <Axes: xlabel='weight', ylabel='height'>

# %% [markdown]
# ---
# https://rathachai.creatier.pro/
#
# ## つづく
